# %%
import pandas as pd
import numpy as np

# %%
pd.read_csv('brewtoad/csv/hops_page_1_to_10.csv')
# Out:
#                              beer_id                          beer_name  \
# 0                 firework-cream-ale            [u'Firework Cream Ale']
# 1                 firework-cream-ale            [u'Firework Cream Ale']
# 2    sierra-nevada-pale-ale-clone-65  [u'Sierra Nevada Pale Ale Clone']
# 3    sierra-nevada-pale-ale-clone-65  [u'Sierra Nevada Pale Ale Clone']
# 4    sierra-nevada-pale-ale-clone-65  [u'Sierra Nevada Pale Ale Clone']
# 5    sierra-nevada-pale-ale-clone-65  [u'Sierra Nevada Pale Ale Clone']
# 6                 citra-amarillo-ipa            [u'Citra/Amarillo IPA']
# 7                 citra-amarillo-ipa            [u'Citra/Amarillo IPA']
# 8                 citra-amarillo-ipa            [u'Citra/Amarillo IPA']
# 9                 citra-amarillo-ipa            [u'Citra/Amarillo IPA']
# 10                citra-amarillo-ipa            [u'Citra/Amarillo IPA']
# 11                citra-amarillo-ipa            [u'Citra/Amarillo IPA']
# ...

# %%
# %run utils.py

# %%
data = load_from_csv(1,10)

# %%
recipe = data['recipes']
style = data['styles']
fermentables = data['fermentables']
hops = data['hops']
yeasts = data['yeasts']
miscs = data['miscs']

# %%
yeasts
# Out:
#                                       beer_id  \
# 0             sierra-nevada-pale-ale-clone-65
# 1                          citra-amarillo-ipa
# 2                               house-red-ale
# 3                                     hefe-iv
# 4                          big-bens-brown-ale
# 5              oatmeal-chocolate-milk-stout-1
# 6                      citra-black-ipa-bc7279
# 7        ashleighs-knock-you-on-your-ass-beer
# 8                  welcome-winter-english-ale
# 9                      winter-warmer-ale-2013
# 10                         mans-best-friend-1
# 11                         vanilla-porter-101
# 12                         gingerbread-porter
# 13                        stored-xss-biab-apa
# 14    biermuncher-centennial-blonde-all-grain
# 15            northern-brewer-dead-ringer-ipa
# 16                              rubaeus-clone
# 17                            belgian-pale-62
# 18                            belgian-pale-62
# ...

# %%
yeasts['beer_id'][1][0]
# Out:
# 'c'

# %%
yeasts['beer_name'][1][0] == '['
# Out:
# True

# %%
float(yeasts['beer_name'][1][3:len(yeasts['attenuation'][1]) - 2])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-51-4846e36df25d> in <module>()
# ----> 1 float(yeasts['beer_name'][1][3:len(yeasts['attenuation'][1]) - 2])
#
# ValueError: could not convert string to float: Citr

# %%
# %run utils.py

# %%
data = format_data(data)
# Out:
# OOO
# OOO
# OOO
# OOO
# OOO
# OOO
# OOO
# OOO
# OOO
# OOO
# OOO
# OOO
# OOO
# OOO
# OOO
# OOO
# OOO
# OOO
# OOO
# OOO
# OOO
# OOO
# OOO
# OOO
# OOO
# OOO
# OOO
# OOO
# OOO
# OOO
# OOO
# OOO
# OOO
# OOO
# OOO
# OOO
# OOO
# OOO
# OOO
# OOO
# OOO
# OOO
# OOO
# OOO
# OOO
# OOO
# OOO
# OOO
# OOO
# OOO
# OOO
# OOO
# OOO
# OOO
# OOO
# OOO
# OOO
# OOO
# OOO
# OOO
# OOO
# OOO
# OOO
# OOO
# OOO
# OOO
# OOO
# OOO
# OOO
# OOO
# OOO
# OOO
# OOO
# OOO
# OOO
# OOO
# OOO
# OOO
# OOO
# OOO
# OOO
# OOO
# OOO
# OOO
# OOO
# OOO
# OOO
# OOO
# OOO
# OOO
# OOO
# OOO
# OOO
# OOO
# OOO
# OOO
# OOO
# OOO
# OOO
# OOO
# OOO
# OOO
# OOO
# OOO
# OOO
# OOO
# OOO
# OOO
# OOO
# OOO
# OOO
# OOO
# OOO
# OOO
# OOO
# OOO
# OOO
# OOO
# OOO
# OOO
# OOO
# OOO
# OOO
# OOO
# OOO
# OOO
# OOO
# OOO
# OOO
# OOO
# OOO
# OOO
# OOO
# OOO
# OOO
# OOO
# OOO
# OOO
# OOO
# OOO
# OOO
# OOO
# OOO
# OOO
# OOO
# OOO
# OOO
# OOO
# OOO
# OOO
# OOO
# OOO
# OOO
# OOO
# OOO
# OOO
# OOO
# OOO
# OOO
# OOO
# OOO
# OOO
# OOO
# OOO
# OOO
# OOO
# ...

# %%
recipe = data['recipes']
style = data['styles']
fermentables = data['fermentables']
hops = data['hops']
yeasts = data['yeasts']
miscs = data['miscs']

# %%
hops
# Out:
#                              beer_id                          beer_name  \
# 0    sierra-nevada-pale-ale-clone-65  [u'Sierra Nevada Pale Ale Clone']
# 1    sierra-nevada-pale-ale-clone-65  [u'Sierra Nevada Pale Ale Clone']
# 2    sierra-nevada-pale-ale-clone-65  [u'Sierra Nevada Pale Ale Clone']
# 3    sierra-nevada-pale-ale-clone-65  [u'Sierra Nevada Pale Ale Clone']
# 4                 citra-amarillo-ipa            [u'Citra/Amarillo IPA']
# 5                 citra-amarillo-ipa            [u'Citra/Amarillo IPA']
# 6                 citra-amarillo-ipa            [u'Citra/Amarillo IPA']
# 7                 citra-amarillo-ipa            [u'Citra/Amarillo IPA']
# 8                 citra-amarillo-ipa            [u'Citra/Amarillo IPA']
# 9                 citra-amarillo-ipa            [u'Citra/Amarillo IPA']
# 10                citra-amarillo-ipa            [u'Citra/Amarillo IPA']
# 11                citra-amarillo-ipa            [u'Citra/Amarillo IPA']
# ...
